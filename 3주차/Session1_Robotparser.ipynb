# %% [markdown]
# # '파이썬' 검색결과 가져오기

# %%
# !pip install builtwith

# %%
from builtwith import builtwith

# %%
builtwith('http://wordpress.com')
# Out:
# {'web-servers': ['Nginx'],
#  'font-scripts': ['Google Font API'],
#  'ecommerce': ['WooCommerce'],
#  'cms': ['WordPress'],
#  'programming-languages': ['PHP'],
#  'blogs': ['PHP', 'WordPress']}

# %%
# !pip install python-whois

# %%
from whois import whois

# %%
whois('http://wordpress.com')
# Out:
# {'domain_name': ['WORDPRESS.COM', 'wordpress.com'],
#  'registrar': 'MarkMonitor, Inc.',
#  'whois_server': 'whois.markmonitor.com',
#  'referral_url': None,
#  'updated_date': [datetime.datetime(2020, 2, 1, 10, 18, 28),
#   datetime.datetime(2020, 2, 1, 2, 18, 28)],
#  'creation_date': [datetime.datetime(2000, 3, 3, 12, 13, 23),
#   datetime.datetime(2000, 3, 3, 4, 13, 23)],
#  'expiration_date': [datetime.datetime(2022, 3, 3, 12, 13, 23),
#   datetime.datetime(2022, 3, 3, 0, 0)],
#  'name_servers': ['NS1.WORDPRESS.COM',
#   'NS2.WORDPRESS.COM',
#   'NS3.WORDPRESS.COM',
#   'NS4.WORDPRESS.COM',
#   'ns1.wordpress.com',
#   'ns3.wordpress.com',
#   'ns4.wordpress.com',
#   'ns2.wordpress.com'],
#  'status': ['clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited',
#   'clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited',
# ...

# %%
from urllib import robotparser

# %%
robot = robotparser.RobotFileParser()
robot.set_url('https://www.google.com/robots.txt')
robot.read()
robot.can_fetch('*', 'https://google.com') # * : 'AgentName'
# Out:
# False

# %%
robot.set_url('http://news.naver.com/robots.txt')
robot.read()
robot.can_fetch('Yeti', '/main/imagemontage')
# Out:
# True

# %%
from urllib.request import urlopen, Request

# %%
resp = urlopen('http://www.google.com/robots.txt')

# %%
resp.getheaders() # ('Content-Type', 'text/plain')
# Out:
# [('Accept-Ranges', 'none'),
#  ('Vary', 'Accept-Encoding'),
#  ('Content-Type', 'text/plain'),
#  ('Date', 'Mon, 03 Aug 2020 02:07:50 GMT'),
#  ('Expires', 'Mon, 03 Aug 2020 02:07:50 GMT'),
#  ('Cache-Control', 'private, max-age=0'),
#  ('Last-Modified', 'Mon, 08 Jun 2020 18:00:00 GMT'),
#  ('X-Content-Type-Options', 'nosniff'),
#  ('Server', 'sffe'),
#  ('X-XSS-Protection', '0'),
#  ('Connection', 'close'),
#  ('Transfer-Encoding', 'chunked')]

# %%
resp.code, resp.info # 메세지, 코드
# Out:
# (200,
#  <bound method HTTPResponse.info of <http.client.HTTPResponse object at 0x000001F74DF984C8>>)

# %%
resp.code, resp.reason
# Out:
# (200, 'OK')

# %%
body = resp.read()

# %%
body.decode('UTF-8').split('\n')
# Out:
# ['User-agent: *',
#  'Disallow: /search',
#  'Allow: /search/about',
#  'Allow: /search/static',
#  'Allow: /search/howsearchworks',
#  'Disallow: /sdch',
#  'Disallow: /groups',
#  'Disallow: /index.html?',
#  'Disallow: /?',
#  'Allow: /?hl=',
#  'Disallow: /?hl=*&',
#  'Allow: /?hl=*&gws_rd=ssl$',
#  'Disallow: /?hl=*&*&gws_rd=ssl',
#  'Allow: /?gws_rd=ssl$',
#  'Allow: /?pt1=true$',
#  'Disallow: /imgres',
#  'Disallow: /u/',
#  'Disallow: /preferences',
#  'Disallow: /setprefs',
#  'Disallow: /default',
#  'Disallow: /m?',
#  'Disallow: /m/',
#  'Allow:    /m/finance',
#  'Disallow: /wml?',
#  'Disallow: /wml/?',
#  'Disallow: /wml/search?',
#  'Disallow: /xhtml?',
#  'Disallow: /xhtml/?',
#  'Disallow: /xhtml/search?',
#  'Disallow: /xml?',
#  'Disallow: /imode?',
#  'Disallow: /imode/?',
#  'Disallow: /imode/search?',
#  'Disallow: /jsky?',
#  'Disallow: /jsky/?',
#  'Disallow: /jsky/search?',
#  'Disallow: /pda?',
#  'Disallow: /pda/?',
#  'Disallow: /pda/search?',
# ...

# %%
[_.split(':') for _ in body.decode('UTF-8').split('\n')]
# Out:
# [['User-agent', ' *'],
#  ['Disallow', ' /search'],
#  ['Allow', ' /search/about'],
#  ['Allow', ' /search/static'],
#  ['Allow', ' /search/howsearchworks'],
#  ['Disallow', ' /sdch'],
#  ['Disallow', ' /groups'],
#  ['Disallow', ' /index.html?'],
#  ['Disallow', ' /?'],
#  ['Allow', ' /?hl='],
#  ['Disallow', ' /?hl=*&'],
#  ['Allow', ' /?hl=*&gws_rd=ssl$'],
#  ['Disallow', ' /?hl=*&*&gws_rd=ssl'],
#  ['Allow', ' /?gws_rd=ssl$'],
#  ['Allow', ' /?pt1=true$'],
#  ['Disallow', ' /imgres'],
#  ['Disallow', ' /u/'],
#  ['Disallow', ' /preferences'],
#  ['Disallow', ' /setprefs'],
#  ['Disallow', ' /default'],
#  ['Disallow', ' /m?'],
#  ['Disallow', ' /m/'],
#  ['Allow', '    /m/finance'],
#  ['Disallow', ' /wml?'],
#  ['Disallow', ' /wml/?'],
#  ['Disallow', ' /wml/search?'],
#  ['Disallow', ' /xhtml?'],
#  ['Disallow', ' /xhtml/?'],
#  ['Disallow', ' /xhtml/search?'],
#  ['Disallow', ' /xml?'],
#  ['Disallow', ' /imode?'],
#  ['Disallow', ' /imode/?'],
# ...

# %%
resp = urlopen('https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&oq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&aqs=chrome..69i57j69i59l2j0j69i61l3j69i65.2418j0j7&sourceid=chrome&ie=UTF-8')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-18-66730e1f2525> in <module>
# ----> 1 resp = urlopen('https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&oq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&aqs=chrome..69i57j69i59l2j0j69i61l3j69i65.2418j0j7&sourceid=chrome&ie=UTF-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...

# %%
html = resp.read().decode('utf-8')

# %%
resp.code, resp.reason, resp.getheaders(), resp.read()
# Out:
# (200,
#  'OK',
#  [('Accept-Ranges', 'none'),
#   ('Vary', 'Accept-Encoding'),
#   ('Content-Type', 'text/plain'),
#   ('Date', 'Mon, 03 Aug 2020 02:07:50 GMT'),
#   ('Expires', 'Mon, 03 Aug 2020 02:07:50 GMT'),
#   ('Cache-Control', 'private, max-age=0'),
#   ('Last-Modified', 'Mon, 08 Jun 2020 18:00:00 GMT'),
#   ('X-Content-Type-Options', 'nosniff'),
#   ('Server', 'sffe'),
#   ('X-XSS-Protection', '0'),
#   ('Connection', 'close'),
#   ('Transfer-Encoding', 'chunked')],
#  b'')

# %%
req = Request(url='https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&oq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&aqs=chrome..69i57j69i59l2j0j69i61l3j69i65.2418j0j7&sourceid=chrome&ie=UTF-8')

# %%
req.headers
# Out:
# {}

# %%
req.add_header('user-agent', '')

# %%
resp = urlopen(req)

# %%
resp.getheaders()
# Out:
# [('Content-Type', 'text/html; charset=ISO-8859-1'),
#  ('Date', 'Mon, 03 Aug 2020 02:08:14 GMT'),
#  ('Expires', '-1'),
#  ('Cache-Control', 'private, max-age=0'),
#  ('P3P', 'CP="This is not a P3P policy! See g.co/p3phelp for more info."'),
#  ('Server', 'gws'),
#  ('X-XSS-Protection', '0'),
#  ('X-Frame-Options', 'SAMEORIGIN'),
#  ('Set-Cookie',
#   '1P_JAR=2020-08-03-02; expires=Wed, 02-Sep-2020 02:08:14 GMT; path=/; domain=.google.com; Secure'),
#  ('Set-Cookie',
#   'CGIC=; expires=Sat, 30-Jan-2021 02:08:14 GMT; path=/complete/search; domain=.google.com; HttpOnly'),
#  ('Set-Cookie',
#   'CGIC=; expires=Sat, 30-Jan-2021 02:08:14 GMT; path=/search; domain=.google.com; HttpOnly'),
#  ('Set-Cookie',
#   'NID=204=gDZlk59n-S_OQzVihcNZGp9-m1mqK27ITdc_e-Mf9ul5-DrQZCLV7ozEDds7zZ4Hfqu7rjbzRiKbQ45vf3WVMOYKaOFkziMDHeMbSYbplIl9UltRcAyaIJoM4BO0Ksu3fUv_s9JahSErcrsdgdMd-efHJWEdFFUZocRVkiRapmA; expires=Tue, 02-Feb-2021 02:08:14 GMT; path=/; domain=.google.com; HttpOnly'),
#  ('Alt-Svc',
# ...

# %%
resp.read().decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-f5badc7cee90> in <module>
# ----> 1 resp.read().decode('utf-8')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd7 in position 13860: invalid continuation byte

# %%
resp = urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC')

# %%
resp.code, resp.reason # print(resp.headers)
# Out:
# (200, 'OK')

# %%
resp.read() # b # byte # 한글이 깨진다
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x8
# ...

# %%
resp = urlopen('https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC')

# %%
resp.code, resp.reason
# Out:
# (200, 'OK')

# %%
resp.read()
# Out:
# b'<script type="text/javascript">\nlocation.replace( "http://ncaptcha.search.daum.net/captcha/show?redirect=http%3A%2F%2Fsearch.daum.net%2Fsearch%3Fw%3Dtot%26DA%3DYZR%26t__nil_searchbox%3Dbtn%26sug%3D%26sugo%3D%26sq%3D%26o%3D%26q%3D%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC" );\n</script>\n'

# %%
resp = urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC')

# %%
resp.read().decode('utf-8')
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="파이썬 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'파이썬\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'파이썬\'의 네이버 통합검색 결과입니다."> <title>파이썬 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200716.css"> <link rel="stylesheet" type="text/css" hr
# ...

# %%
resp.geturl()
# Out:
# 'https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
url = 'https://search.naver.com/search.naver?query=파이썬'
resp = urlopen(url)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-36-641b5e04ef2d> in <module>
#       1 url = 'https://search.naver.com/search.naver?query=파이썬'
# ----> 2 resp = urlopen(url)
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# ...

# %%
resp = urlopen(url.encode('utf8'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-5beca6c21a01> in <module>
# ----> 1 resp = urlopen(url.encode('utf8'))
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     514                 req.data = data
#     515
# --> 516         req.timeout = timeout
#     517         protocol = req.type
#     518
#
# AttributeError: 'bytes' object has no attribute 'timeout'

# %%
url.encode('utf8')
# Out:
# b'https://search.naver.com/search.naver?query=\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac'

# %%
from urllib.parse import urlparse, urljoin, urlencode, quote, quote_plus

# %%
quote('파이썬'), quote_plus('파 이 썬')
# Out:
# ('%ED%8C%8C%EC%9D%B4%EC%8D%AC', '%ED%8C%8C+%EC%9D%B4+%EC%8D%AC')

# %%
from urllib.parse import unquote, unquote_plus

# %%
unquote('%ED%8C%8C%EC%9D%B4%EC%8D%AC')
# Out:
# '파이썬'

# %%
unquote('%ED%8C%8C+%EC%9D%B4+%EC%8D%AC')
# Out:
# '파+이+썬'

# %%
unquote_plus('%ED%8C%8C+%EC%9D%B4+%EC%8D%AC')
# Out:
# '파 이 썬'

# %%
urlencode({'key':'파이썬'})
# Out:
# 'key=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
url = 'https://search.naver.com/search.naver?query='+quote('파이썬')
resp = urlopen(url)

# %%
resp.read().decode('utf8')
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="파이썬 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'파이썬\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'파이썬\'의 네이버 통합검색 결과입니다."> <title>파이썬 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200716.css"> <link rel="stylesheet" type="text/css" hr
# ...

# %%
url = 'https://www.google.com/search'
params = {
    'q':'',
    'aqs':'chrome..69i57.2373j1j7',
    'souceid':'chrome',
    'ie':'UTF-8'
}
params['q'] = quote('파이썬')
params
# Out:
# {'q': '%ED%8C%8C%EC%9D%B4%EC%8D%AC',
#  'aqs': 'chrome..69i57.2373j1j7',
#  'souceid': 'chrome',
#  'ie': 'UTF-8'}

# %%
urlencode(params) # (=params)
# Out:
# 'q=%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC&aqs=chrome..69i57.2373j1j7&souceid=chrome&ie=UTF-8'

# %%
quote('파이썬')
# Out:
# '%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
url + '?' + urlencode(params)
# Out:
# 'https://www.google.com/search?q=%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC&aqs=chrome..69i57.2373j1j7&souceid=chrome&ie=UTF-8'

# %%
resp = urlopen(url + '?' + urlencode(params))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-53-998a3df7f993> in <module>
# ----> 1 resp = urlopen(url + '?' + urlencode(params))
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# ...

# %%
req = Request(url + '?' + urlencode(params), headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'})

# %%
req.headers
# Out:
# {'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'}

# %%
resp = urlopen(req)

# %%
resp.read().decode('utf8')
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title>%ED%8C%8C%EC%9D%B4%EC%8D%AC - Google 검색</title><script nonce="ji0gvOq4+5CLcqTQLN/5jA==">(function(){window.google={kEI:\'bYgnX9afC7eVr7wPv6C7mAc\',kEXPI:\'31\',kBL:\'YyCE\'};google.sn=\'web\';google.kHL=\'ko\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var c;a&&(!a.getAttribute||!(c=a.getAttribute("eid")));)a=a.parentNode;return c||google.kEI};google.getLEI=function(a){for(var c=null;a&&(!a.getAttribute||!(c=a.getAttribute("leid")));)a=a.parentNode;return c};google.ml=function(){return null};google.time=function(){return Date.now()};google.log=function(a,c,b,d,g){if(b=google.logUrl(a,c,b,d,g)){a=new Image;var e=google.lc,f=google.li;e[f]=a;a.onerror=a.onload=a.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&goog
# ...

# %%
from urllib.error import HTTPError

try:
    resp = urlopen(url + '?' + urlencode(params))
except HTTPError as e:
    print(e.code)
    print(e.reason)
    print(e.headers)
# Out:
# 403
# Forbidden
# Content-Type: text/html; charset=UTF-8
# Date: Mon, 03 Aug 2020 03:46:08 GMT
# Server: gws
# Cache-Control: private
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Alt-Svc: h3-29=":443"; ma=2592000,h3-27=":443"; ma=2592000,h3-T050=":443"; ma=2592000,h3-Q050=":443"; ma=2592000,h3-Q046=":443"; ma=2592000,h3-Q043=":443"; ma=2592000,quic=":443"; ma=2592000; v="46,43"
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
# Transfer-Encoding: chunked

# %%
url = 'http://httpbin.org/get?key=value'
resp = urlopen(url)
print(resp.headers)
print(resp.read().decode('utf-8'))
# Out:
# Date: Mon, 03 Aug 2020 03:46:53 GMT
# Content-Type: application/json
# Content-Length: 306
# Connection: close
# Server: gunicorn/19.9.0
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
#
#
# {
#   "args": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept-Encoding": "identity",
#     "Host": "httpbin.org",
#     "User-Agent": "Python-urllib/3.7",
#     "X-Amzn-Trace-Id": "Root=1-5f2788ad-cd9a047f3d0061a451744fdf"
#   },
#   "origin": "163.152.3.134",
#   "url": "http://httpbin.org/get?key=value"
# }

# %%
url = 'http://httpbin.org/post?k=v'
params = {
    'key':'value',
    'name':'한글'
}
resp = urlopen(Request(url=url, data=urlencode(params).encode('utf-8'), method='POST'))
print(resp.headers)
print(resp.read().decode('utf-8'))
# Out:
# Date: Mon, 03 Aug 2020 03:47:40 GMT
# Content-Type: application/json
# Content-Length: 496
# Connection: close
# Server: gunicorn/19.9.0
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
#
#
# {
#   "args": {
#     "k": "v"
#   },
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value",
#     "name": "\ud55c\uae00"
#   },
#   "headers": {
#     "Accept-Encoding": "identity",
#     "Content-Length": "33",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "Python-urllib/3.7",
#     "X-Amzn-Trace-Id": "Root=1-5f2788dc-8a8f98403eb3c200abcae180"
#   },
#   "json": null,
#   "origin": "163.152.3.134",
#   "url": "http://httpbin.org/post?k=v"
# }

# %%
url
# Out:
# 'http://httpbin.org/post?k=v'

# %%
urlparse(url)
# Out:
# ParseResult(scheme='http', netloc='httpbin.org', path='/post', params='', query='k=v', fragment='')

# %%
tokens = urlparse(url)
tokens[1] + '/get' # tokens[2]
# Out:
# 'httpbin.org/get'

# %%
import requests

# %%
resp = requests.get('http://httpbin.org/get?key=한글')

# %%
resp.headers
# Out:
# {'Date': 'Mon, 03 Aug 2020 03:56:06 GMT', 'Content-Type': 'application/json', 'Content-Length': '352', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
resp.content.decode('utf-8') # 번거로움
# Out:
# '{\n  "args": {\n    "key": "\\ud55c\\uae00"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.24.0", \n    "X-Amzn-Trace-Id": "Root=1-5f278ad6-e319bf00c2f72c44e245c948"\n  }, \n  "origin": "163.152.3.134", \n  "url": "http://httpbin.org/get?key=\\ud55c\\uae00"\n}\n'

# %%
resp.text # -> 제공하고 있음
# Out:
# '{\n  "args": {\n    "key": "\\ud55c\\uae00"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.24.0", \n    "X-Amzn-Trace-Id": "Root=1-5f278ad6-e319bf00c2f72c44e245c948"\n  }, \n  "origin": "163.152.3.134", \n  "url": "http://httpbin.org/get?key=\\ud55c\\uae00"\n}\n'

# %%
resp.encoding = 'euc-kr'

# %%
resp.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
resp.text.split('\n')
# Out:
# ['{',
#  '  "args": {',
#  '    "key": "\\ud55c\\uae00"',
#  '  }, ',
#  '  "headers": {',
#  '    "Accept": "*/*", ',
#  '    "Accept-Encoding": "gzip, deflate", ',
#  '    "Host": "httpbin.org", ',
#  '    "User-Agent": "python-requests/2.24.0", ',
#  '    "X-Amzn-Trace-Id": "Root=1-5f278ad6-e319bf00c2f72c44e245c948"',
#  '  }, ',
#  '  "origin": "163.152.3.134", ',
#  '  "url": "http://httpbin.org/get?key=\\ud55c\\uae00"',
#  '}',
#  '']

# %%
resp = requests.get('https://www.google.com/search?q=파이썬&oe=utf-8')

# %%
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# '<!doctype html><html lang="ko"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>파이썬 - Google 검색</title><script nonce="K/RxICnBy5MuCva01h0JIw==">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){\nvar a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};var h=fun
# ...

# %%
requests.post('http://httpbin.org')
# Out:
# <Response [405]>

# %%
resp = requests.post('http://httpbin.org/post?ie=utf-8',)

# %%
resp = requests.get('http://httpbin.org/status/200')
print(resp.text)
print(resp.status_code)
print(resp.reason)
print(resp.headers)
print(resp.request.headers)
# Out:
# 200
# OK
# {'Date': 'Mon, 03 Aug 2020 03:58:27 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '0', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
resp = requests.get('http://httpbin.org/status/403')
print(resp.text)
print(resp.status_code)
print(resp.reason)
print(resp.headers)
print(resp.request.headers)
# Out:
# 403
# FORBIDDEN
# {'Date': 'Mon, 03 Aug 2020 03:58:31 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '0', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
resp = requests.get('http://httpbin.org/status/403')
if (resp.status_code != 200):
    print(resp.reason)
# resp.raise_for_status()
# Out:
# FORBIDDEN

# %%
resp = requests.get('http://httpbin.org/image/jpeg')
resp.headers
# Out:
# {'Date': 'Mon, 03 Aug 2020 03:58:58 GMT', 'Content-Type': 'image/jpeg', 'Content-Length': '35588', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
resp.headers.get('Content-Type').split('/')[0] == 'image'
# Out:
# True

# %%
resp.headers.get('Content-Type').split('/')[1]
# Out:
# 'jpeg'

# %%
file = 'test.' + resp.headers.get('Content-Type').split('/')[1]

# %%
with open (file, 'wb') as f:
    f.write(resp.content)

# %%
from urllib.robotparser import RobotFileParser

# %%
robot = RobotFileParser()

# %%
robot.set_url('http://httpbin.org/robots.txt')
robot.read()
robot.can_fetch('*', '/deny')
# Out:
# False

# %%
from requests.compat import urlparse, urljoin

# %%
def canfetch(url, agent='*', path='/'):
    robot = RobotFileParser(urljoin(url, 'robots.txt'))
    robot.read()
    return robot.can_fetch(agent, urlparse(url)[2])

def download(url, params={}, headers={}, method='GET', limit=3):
    if canfetch(url) == False:
        print('[Error] ' + url)
#     else:
    try:
        resp = requests.request(method, url,
               params=params if method=='GET' else {},
               data=params if method=='POST' else {},
               headers=headers)
        resp.raise_for_status()
    except HTTPError as e:
        if limit > 0 and e.response.status_code >= 500:
            print(limit)
            time.sleep(1) # => random
            resp = download(url, params, headers, method, limit-1)
        else:
            print('[{}] '.format(e.response.status_code) + url)
            print(e.response.status_code)
            print(e.response.reason)
            print(e.response.headers)
    return resp

# %%
download(url='http://httpbin.org/deny')
# Out:
# [Error] http://httpbin.org/deny
# <Response [200]>

# %%
download('http://httpbin.org/post', {'k':'v'}, method='POST')
# Out:
# <Response [200]>

# %%
download('http://httpbin.org/post', {'k':'v'}, method='GET')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-94-1eda09de582f> in <module>
# ----> 1 download('http://httpbin.org/post', {'k':'v'}, method='GET')
#
# <ipython-input-91-1bf013351096> in download(url, params, headers, method, limit)
#      13                data=params if method=='POST' else {},
#      14                headers=headers)
# ---> 15         resp.raise_for_status()
#      16     except HTTPError as e:
#      17         if limit > 0 and e.response.status_code >= 500:
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#     943     def close(self):
#
# HTTPError: 405 Client Error: METHOD NOT ALLOWED for url: http://httpbin.org/post?k=v

# %%
resp.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
url = 'https://search.naver.com/search.naver'
params = {
    'sm':'top_hty',
    'fbm':0,
    'ie':'utf8',
    'query':''   
}
params['query'] = '파이썬'
headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
}
resp = download(url, params, headers, 'GET')
resp.text
# Out:
# [Error] https://search.naver.com/search.naver
# ...

# %%
url = 'https://search.daum.net/search'
params = {
    'w':'tot',
    'DA':'YZR',
    't__nil_searchbox':'btn',
    'sug':'',
    'sugo':'',
    'sq':'',
    'o':'',
    'q':''
}
params['q'] = '파 이 썬'
headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
}
resp = download(url, params, headers, 'GET')
resp.text
# Out:
# [Error] https://search.daum.net/search
# ...

# %%
from requests.compat import urlparse, urljoin
from requests.exceptions import HTTPError
import time

# %%
url = 'https://www.google.com/search'
params = {
    'q':'',
    'oq':'',
    'aqs':'chrome..69i57j69i59j69i65l3j69i61j69i60j69i61.1205j0j7',
    'sourceid':'chrome',
    'ie':'UTF-8'
}
params['q'] = params['oq'] = '파 이 썬'
headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
}
resp = download(url, params, headers, 'GET')
resp.text
# Out:
# [Error] https://www.google.com/search
# ...

# %%
resp.request.headers
# Out:
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
url = 'http://www.moel.go.kr/searchapi/search_json.jsp'
params = {
    'query': '최저임금',
    'prefixQuery': 'LOCAL1|LOCAL2|LOCAL3|LOCAL4|LOCAL5|LOCAL6',
    'requery': '',
    'sort': 'RANK',
    'sortOrder': 'DESC',
    'startCount': '',
    'listCount': '10',
    'sitecd': 'seoul'
}
params['query'] = '최저임금'
resp = download(url, params, headers, 'POST')
#resp = download(url, {'query':'최저임금'}, headers, 'GET')
resp.text
# Out:
# '\r\n\r\n\r\n\r\n{"SearchQueryResult":{"Version":"5.3.0","SuggestedQuery":"","Collection":[{"Id":"moel","MorphemeAnalysis":{"Field":{"TITLE":"최저임금 최저 임금","CONTENTS":"최저임금 최저 임금","ATTACH_NM":"최저임금 최저 임금","ATTACH_CON":"최저임금 최저 임금","INPUT_NAME":"최저임금"}},"DocumentSet":{"Count":"10","TotalCount":"654","Document":[{"Uid":"170219","Rank":"50","Date":"2006/07/27 10:25:00","Weight":"0","SearcherId":"sc","CollectionId":"moel","DuplicateDocumentCount":"1","Field":{"DOCID":"LOCAL5_62580","BBS_ID":"LOCAL5","BBS_SEQ":"62580","BBS_NM":"부서별자료실","BBS_DESC":"","TITLE":"감시단속적 근로자에 대한 <!HS>최저임금<!HE> 감액률 연구","CONTENTS":"<!HS>최저임금<!HE>법 개정(\'05.5.31)으로 감시·단속적 근로자에 대하여 <!HS>최저임금<!HE>액을 감액하여 적용하게 됨에 따라 그 감액률을 합리적인 수준에서 감액률을 정할 수 있도록 연구용역을 시행하였으니 참조하시기 바랍니다.","ATTACH_SEQ":"21171050452","ATTACH_NM":"최종(060615).hwp","ATTACH_CON":"... 초과근로시간 41.4 23 8 7 E A/D_1 6,659 6,703 3,080 6,046 F B/D 7,515 7,783 3,471 6,895 G C/D - - 3,977 - H <!HS>최저임금<!HE> 2,510 I E 기준  <!HS>최저<!HE> <!HS>임금<!HE> 이하 근로자 비율 0.55% 3.93% 5
# ...

# %%
resp.request.url, resp.request.body
# Out:
# ('http://www.moel.go.kr/searchapi/search_json.jsp',
#  'query=%EC%B5%9C%EC%A0%80%EC%9E%84%EA%B8%88&prefixQuery=LOCAL1%7CLOCAL2%7CLOCAL3%7CLOCAL4%7CLOCAL5%7CLOCAL6&requery=&sort=RANK&sortOrder=DESC&startCount=&listCount=10&sitecd=seoul')

# %%
resp.text
# Out:
# '\r\n\r\n\r\n\r\n{"SearchQueryResult":{"Version":"5.3.0","SuggestedQuery":"","Collection":[{"Id":"moel","MorphemeAnalysis":{"Field":{"TITLE":"최저임금 최저 임금","CONTENTS":"최저임금 최저 임금","ATTACH_NM":"최저임금 최저 임금","ATTACH_CON":"최저임금 최저 임금","INPUT_NAME":"최저임금"}},"DocumentSet":{"Count":"10","TotalCount":"654","Document":[{"Uid":"170219","Rank":"50","Date":"2006/07/27 10:25:00","Weight":"0","SearcherId":"sc","CollectionId":"moel","DuplicateDocumentCount":"1","Field":{"DOCID":"LOCAL5_62580","BBS_ID":"LOCAL5","BBS_SEQ":"62580","BBS_NM":"부서별자료실","BBS_DESC":"","TITLE":"감시단속적 근로자에 대한 <!HS>최저임금<!HE> 감액률 연구","CONTENTS":"<!HS>최저임금<!HE>법 개정(\'05.5.31)으로 감시·단속적 근로자에 대하여 <!HS>최저임금<!HE>액을 감액하여 적용하게 됨에 따라 그 감액률을 합리적인 수준에서 감액률을 정할 수 있도록 연구용역을 시행하였으니 참조하시기 바랍니다.","ATTACH_SEQ":"21171050452","ATTACH_NM":"최종(060615).hwp","ATTACH_CON":"... 초과근로시간 41.4 23 8 7 E A/D_1 6,659 6,703 3,080 6,046 F B/D 7,515 7,783 3,471 6,895 G C/D - - 3,977 - H <!HS>최저임금<!HE> 2,510 I E 기준  <!HS>최저<!HE> <!HS>임금<!HE> 이하 근로자 비율 0.55% 3.93% 5
# ...

# %%
result = resp.json()

# %%
for _ in result['SearchQueryResult']['Collection']:
    print(_['DocumentSet']['Document'])
# Out:
# [{'Uid': '170219', 'Rank': '50', 'Date': '2006/07/27 10:25:00', 'Weight': '0', 'SearcherId': 'sc', 'CollectionId': 'moel', 'DuplicateDocumentCount': '1', 'Field': {'DOCID': 'LOCAL5_62580', 'BBS_ID': 'LOCAL5', 'BBS_SEQ': '62580', 'BBS_NM': '부서별자료실', 'BBS_DESC': '', 'TITLE': '감시단속적 근로자에 대한 <!HS>최저임금<!HE> 감액률 연구', 'CONTENTS': "<!HS>최저임금<!HE>법 개정('05.5.31)으로 감시·단속적 근로자에 대하여 <!HS>최저임금<!HE>액을 감액하여 적용하게 됨에 따라 그 감액률을 합리적인 수준에서 감액률을 정할 수 있도록 연구용역을 시행하였으니 참조하시기 바랍니다.", 'ATTACH_SEQ': '21171050452', 'ATTACH_NM': '최종(060615).hwp', 'ATTACH_CON': '... 초과근로시간 41.4 23 8 7 E A/D_1 6,659 6,703 3,080 6,046 F B/D 7,515 7,783 3,471 6,895 G C/D - - 3,977 - H <!HS>최저임금<!HE> 2,510 I E 기준  <!HS>최저<!HE> <!HS>임금<!HE> 이하 근로자 비율 0.55% 3.93% 53.07% 1.39% <!HS>최저<!HE> <!HS>임금<!HE> 이하 근로자수 103 1,588 91,757 254 J F 기준  <!HS>최저<!HE> <!HS>임금<!HE> 이하 근로자 비율 0.11% 0.35% 46.21% 0.01% <!HS>최저<!HE> <!HS>임금<!HE> 이하 근로자수 20 141 79,900 2 (단위: 원, 시간, 명, %) 주: " - "는 ...', 'HIT': '252', 'REPLY': '', 'EMAIL': '', 'TEL': '02)2250-
# ...

# %%
url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'
params = {
    'ServiceKey':'Jc3XeQDEjqMf5a%2FfKvEePkgOhsvUVDOEO9o4MCDe0IpqGZTHix9rug0VeLCiDNA%2BTt7Q3fgx%2F7SptE5pPTGlRw%3D%3D',
    'numOfRows':10,
    'pageNo':1,
    'stationName':'종로구',
    'dataTerm':'DAILY',
    'ver':'1.3',
    '_returnType':'json'
}
resp = download(url, params, headers, 'GET')
resp.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>30</resultCode>\r\n\t\t<resultMsg>SERVICE KEY IS NOT REGISTERED ERROR. Please ask data.go.kr</resultMsg>\r\n\t</header>\r\n</response>\r\n'

# %%
urlparse(resp.request.url)[4].split('&')[0].split('=')[-1]
# Out:
# 'Jc3XeQDEjqMf5a%252FfKvEePkgOhsvUVDOEO9o4MCDe0IpqGZTHix9rug0VeLCiDNA%252BTt7Q3fgx%252F7SptE5pPTGlRw%253D%253D'

# %%
params['ServiceKey']
# Out:
# 'Jc3XeQDEjqMf5a%2FfKvEePkgOhsvUVDOEO9o4MCDe0IpqGZTHix9rug0VeLCiDNA%2BTt7Q3fgx%2F7SptE5pPTGlRw%3D%3D'

# %%
# %25 -> % 인코딩 -> 아스키코드 외에 다른 게 있다

# %%
quote(params['ServiceKey'])
# Out:
# 'Jc3XeQDEjqMf5a%252FfKvEePkgOhsvUVDOEO9o4MCDe0IpqGZTHix9rug0VeLCiDNA%252BTt7Q3fgx%252F7SptE5pPTGlRw%253D%253D'

# %%
params['ServiceKey'] = unquote(params['ServiceKey']) # 역으로

# %%
resp = download(url, params, headers, 'GET')
resp.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>30</resultCode>\r\n\t\t<resultMsg>SERVICE KEY IS NOT REGISTERED ERROR. Please ask data.go.kr</resultMsg>\r\n\t</header>\r\n</response>\r\n'

# %%
# params['pageNo'] = 2 # 두 번째 페이지를 보고싶으면
