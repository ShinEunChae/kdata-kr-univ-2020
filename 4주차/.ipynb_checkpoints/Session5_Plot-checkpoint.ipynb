# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5));

# %%
plt.plot([1,2,3])

# %%
plt.title('test')
# Out:
# Text(0.5, 1.0, 'test')

# %%
plt.axes(polar=True)
# Out:
# <PolarAxesSubplot:>

# %%
plt.axes((0,0,0.5,0.5))
plt.title('test2')
plt.axes((0.5,0.5,0.5,0.5))
plt.title('test1')
# Out:
# Text(0.5, 1.0, 'test1')

# %%
plt.style.use('ggplot')

# %%
plt.plot([1,2,3])
plt.xlabel('xlabel')
plt.ylabel('ylabel')
# plt.xticks([1,2])
# plt.yticks([1,2,3])
plt.xlim([2,3])
# Out:
# (2.0, 3.0)

# %%
plt.plot([1,2,3])
plt.grid(False)

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
plt.style.use('grayscale')

# %%
sns.pairplot(iris, hue='species')

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.title('test')
plt.subplot(223)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2)

# %%
ax
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.set_title('test') # state machine 방식이 아니라서 순서와 상관없이 이름을 붙일 수 있음 -> 객체지향 방식
# Out:
# Text(0.5, 1.0, 'test')

# %%
tips = sns.load_dataset('tips')

# %%
t = tips.groupby('sex').mean().plot.bar()

# %%
t = tips.groupby('sex').mean().plot(kind='bar', figsize=(10,5), ylim=(15,20))
