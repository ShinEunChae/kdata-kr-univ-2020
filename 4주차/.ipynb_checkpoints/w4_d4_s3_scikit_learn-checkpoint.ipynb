# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
# load_iris: snake 방식 -> callable 즉 함수처럼 사용

# %%
data = load_iris()

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']

# %%
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
data.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
pd.DataFrame(data.data)
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
# 2차원의 직사각형 형태는 데이터 안으로 들어간다

# %%
pd.DataFrame(data.data, columns=data.feature_names)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris = pd.DataFrame(data.data, columns=data.feature_names)

# %%
iris['target'] = data.target

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris2 = iris.copy()

# %%
target = pd.DataFrame(data.target, columns=['target'])

# %%
pd.concat([iris, target], axis=1)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target  target
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(iris.iloc[:,:-1], iris.target) # target한 series
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
from sklearn.model_selection import train_test_split

# %%
len(train_test_split(iris))
# Out:
# 2

# %%
train, test = train_test_split(iris, test_size=.5) # train data, test data로 unpacking

# %%
train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 139                6.9               3.1                5.4               2.1
# 56                 6.3               3.3                4.7               1.6
# 55                 5.7               2.8                4.5               1.3
# 93                 5.0               2.3                3.3               1.0
# 30                 4.8               3.1                1.6               0.2
# ..                 ...               ...                ...               ...
# 67                 5.8               2.7                4.1               1.0
# 44                 5.1               3.8                1.9               0.4
# 131                7.9               3.8                6.4               2.0
# 54                 6.5               2.8                4.6               1.5
# 83                 6.0               2.7                5.1               1.6
#
#      target
# 139       2
# ...

# %%
test
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 23                5.1               3.3                1.7               0.5
# 5                 5.4               3.9                1.7               0.4
# 31                5.4               3.4                1.5               0.4
# 77                6.7               3.0                5.0               1.7
# 16                5.4               3.9                1.3               0.4
# ..                ...               ...                ...               ...
# 99                5.7               2.8                4.1               1.3
# 51                6.4               3.2                4.5               1.5
# 37                4.9               3.6                1.4               0.1
# 84                5.4               3.0                4.5               1.5
# 14                5.8               4.0                1.2               0.2
#
#     target
# 23       0
# 5        0
# ...

# %%
train, test = train_test_split(iris, random_state=1)

# %%
train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 54                 6.5               2.8                4.6               1.5
# 108                6.7               2.5                5.8               1.8
# 112                6.8               3.0                5.5               2.1
# 17                 5.1               3.5                1.4               0.3
# 119                6.0               2.2                5.0               1.5
# ..                 ...               ...                ...               ...
# 133                6.3               2.8                5.1               1.5
# 137                6.4               3.1                5.5               1.8
# 72                 6.3               2.5                4.9               1.5
# 140                6.7               3.1                5.6               2.4
# 37                 4.9               3.6                1.4               0.1
#
#      target
# 54        1
# ...

# %%
train, test = train_test_split(iris, stratify=iris.target)

# %%
train.target.value_counts() # 뭐 어떨 때? y값 비율을 맞춘다
# Out:
# 1    38
# 2    37
# 0    37
# Name: target, dtype: int64

# %%
X_train, X_test,  y_train, y_test\
= train_test_split(iris.iloc[:,:-1], iris.target) # 미리 쪼개놓고 시작하면 편하다

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# %%
cross_val_score(KNeighborsClassifier(), X_train, y_train, cv=10, n_jobs=-1)
# Out:
# array([0.83333333, 0.91666667, 1.        , 0.90909091, 0.90909091,
#        1.        , 0.90909091, 1.        , 1.        , 1.        ])

# %%
cross_val_score(KNeighborsClassifier(), SVC(), X_train, y_train, cv=10, n_jobs=-1) # 데이터가 작을 땐 cross_val_score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-4f9e8d30dee0> in <module>
# ----> 1 cross_val_score(KNeighborsClassifier(), SVC(), X_train, y_train, cv=10, n_jobs=-1) # 데이터가 작을 땐 cross_val_score
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     219
# ...

# %%
# 마지막 오류 수정 필요
