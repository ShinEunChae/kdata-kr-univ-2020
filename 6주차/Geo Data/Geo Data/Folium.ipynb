# %%
# !pip install -U folium
# Out:
# Requirement already up-to-date: folium in c:\users\shin\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied, skipping upgrade: jinja2>=2.9 in c:\users\shin\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\shin\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in c:\users\shin\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied, skipping upgrade: requests in c:\users\shin\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\shin\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\shin\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\shin\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\shin\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\shin\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'c:\users\shin\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import folium

# %%
dir(folium)
# Out:
# ['Choropleth',
#  'Circle',
#  'CircleMarker',
#  'ClickForMarker',
#  'ColorLine',
#  'ColorMap',
#  'CssLink',
#  'CustomIcon',
#  'Div',
#  'DivIcon',
#  'Element',
#  'FeatureGroup',
#  'Figure',
#  'FitBounds',
#  'GeoJson',
#  'GeoJsonPopup',
#  'GeoJsonTooltip',
#  'Html',
#  'IFrame',
#  'Icon',
#  'JavascriptLink',
#  'LatLngPopup',
#  'LayerControl',
#  'LinearColormap',
#  'Link',
#  'MacroElement',
#  'Map',
#  'Marker',
#  'PolyLine',
#  'Polygon',
#  'Popup',
#  'Rectangle',
#  'RegularPolygonMarker',
#  'StepColormap',
#  'TileLayer',
#  'Tooltip',
#  'TopoJson',
#  'Vega',
#  'VegaLite',
#  'WmsTileLayer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'branca',
#  'features',
#  'folium',
#  'map',
#  'raster_layers',
#  'sys',
#  'utilities',
#  'vector_layers']

# %%
m = folium.Map([37.5665, 126.9780],zoom_start=15)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain')

# folium.Marker([37.5248, 126.9375], popup='<i>문근영</i>', 
# icon=folium.Icon(icon='cloud')).add_to(m3)
folium.Marker([37.5311, 126.9113], popup='<b>Timberline Lodge</b>').add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
# folium.Circle(radius=100, 
# location= [37.5248, 126.9375],
# popup='The Waterfront', 
# color='crimson', 
# fill=False, 
# ).add_to(m4)

folium.CircleMarker(
location=[37.5311, 126.9113], 
radius=50, 
popup='Laurelhurst Park', 
color='#3186cc', 
fill=True, 
fill_color='#3186cc' 
).add_to(m4)
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m5 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
m5.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m6 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 
m6.add_child(folium.ClickForMarker(popup="ClickPoint"))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m7 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    popup='polygon1',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=5
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    popup='polygon2',
    fill_color='#45647d',
    number_of_sides=4,
    radius=10
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    popup='polygon3',
    fill_color='#769d96',
    number_of_sides=6,
    radius=15
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    popup='polygon4',
    fill_color='#769d96',
    number_of_sides=8,
    radius=20
    ).add_to(m7)
m7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

# %%
# !pip install vincent
# Out:
# Collecting vincent
#   Downloading vincent-0.4.4.tar.gz (29 kB)
# Requirement already satisfied: pandas in c:\users\shin\anaconda3\lib\site-packages (from vincent) (1.1.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\shin\anaconda3\lib\site-packages (from pandas->vincent) (2019.3)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\shin\anaconda3\lib\site-packages (from pandas->vincent) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\shin\anaconda3\lib\site-packages (from pandas->vincent) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\shin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->vincent) (1.15.0)
# Building wheels for collected packages: vincent
#   Building wheel for vincent (setup.py): started
#   Building wheel for vincent (setup.py): finished with status 'done'
#   Created wheel for vincent: filename=vincent-0.4.4-py3-none-any.whl size=35173 sha256=20d2a9cc689f249d6863eb74cb2bf4a81c0c35dd00c51619d32e42bac991f598
#   Stored in directory: c:\users\shin\appdata\local\pip\cache\wheels\8a\82\70\830a62b316859479b700063f828a1e13fcdc403dd89dcbeca2
# Successfully built vincent
# Installing collected packages: vincent
# Successfully installed vincent-0.4.4
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'c:\users\shin\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# %%writefile test.json
# {
#   "mark": "bar",
#   "encoding": {
#     "x": {"field": "sex", "type": "nominal"},
#     "y": {"field": "tip", "type": "quantitative"}
#   },
#   "$schema": "https://vega.github.io/schema/vega-lite/v2.json",
#   "width": 450,
#   "height": 300,
#   "selection": {
#     "grid": {
#       "type": "interval",
#       "bind": "scales",
#       "on": "[mousedown, window:mouseup] > window:mousemove!",
#       "encodings": ["x", "y"],
#       "translate": "[mousedown, window:mouseup] > window:mousemove!",
#       "zoom": "wheel!",
#       "mark": {"fill": "#333", "fillOpacity": 0.125, "stroke": "white"},
#       "resolve": "global"
#     }
#   },
#   "data": {
#     "values": [
#       {"sex": "Male", "tip": 3.0896178343949052},
#       {"sex": "Female", "tip": 2.833448275862069}
#     ]
#   }
# }
# Out:
# Overwriting test.json

# %%
import vincent
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
bar.to_json('asset/vis1.json')

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Categories')
line.to_json('asset/vis2.json')

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='index')
scatter.axis_titles(x='Index', y='Data Value')
scatter.legend(title='Categories')
scatter.colors(brew='Set3')
scatter.to_json('asset/vis3.json')

# %%
area = vincent.Area(list_data)
area.to_json('asset/vis4.json')

# %%
import json
m8 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    fill_color='#132b5e',
    radius=5,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis1.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    fill_color='#45647d',
    radius=10,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis2.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    fill_color='#769d96',
    radius=15,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis3.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    fill_color='#769d96',
    radius=20,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis4.json')), width=450, height=250))
    ).add_to(m8)
m8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# seoul_topo_json = open('asset/seoul_municipalities_topo_simple.json', encoding='utf8')
# seoul_topo_json = json.load(seoul_topo_json)

seoul_geo_json = open('asset/seoul_municipalities_geo_simple.json',encoding='utf-8')
seoul_geo_json = json.load(seoul_geo_json)

# %%
m9 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

folium.GeoJson(seoul_geo_json,name='geojson').add_to(m9)

# folium.TopoJson(seoul_topo_json,"objects.seoul_municipalities_geo",name='topojson').add_to(m9)

folium.LayerControl().add_to(m9)
m9
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data = pd.DataFrame.from_dict(seoul_geo_json['features'])
# .properties
# data = pd.DataFrame.from_dict(seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']).properties

# %%
data['xx']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xx'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-cd394e4dc0df> in <module>
# ----> 1 data['xx']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'xx'

# %%
t = data.geometry.map(lambda x:len(x['coordinates'][0]))

# %%
t[t==93]

# %%
t = pd.DataFrame.from_dict(data.properties)

# %%
seoul_df = pd.DataFrame.from_dict(data_list)

# %%
seoul_df

# %%
seoul_df.to_csv('seoul_geo_df.csv')

# %%
m10 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

seoul_geo_df = pd.read_csv('asset/seoul_geo_df.csv')
m10.choropleth(
    geo_data=seoul_geo_json,
    name='choropleth',
    data=seoul_geo_df,
    columns=['name', 'code'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Seoul_choropleth'
)

# %%
m10
